# %% [markdown]
# # CNBC Crawler
#
# Basierend auf den Inhalten, die beim Aufruf der Seite https://www.cnbc.com/search/?query=boeing&qsearchterm=boeing geladen werden, wird die Schnittstelle direkt mittels Requests aufgerufen um die Daten zu laden.
#
# Der untenstehende Code ruft direkt api.queryly.com mit den passenden Kennwerten auf. Um das Netzwerk nicht zu belasten und eine Sperre inkaufnehemen zu müssen, wird der Code in Intervallen aufgerufen. Dabei wird nach jedem mal laden von 10 Inhalten, eine Pause zwischen 2-10 Sekunden gehalten.

# %% [markdown]
# ![alt text](screenshots/1.png "1")

# %%
import requests
import json
import time
import random
import math

# Funktion zum Speichern der Daten
def save_data(all_data, filename='CNBC_articles.json'):
    with open(filename, 'w') as file:
        json.dump(all_data, file, indent=4)
    print("Daten wurden erfolgreich zwischengespeichert.")

# URL und Basis-Parameter für die GET-Anfrage
url = "https://api.queryly.com/cnbc/json.aspx"
queryly_key = "31a35d40a9a64ab3"
batch_size = 10  # Stellen Sie sicher, dass dies der Batchsize Ihrer Anfrage entspricht
params = {
    "queryly_key": queryly_key,
    "query": "boeing",
    "batchsize": batch_size,
    "callback": "",
    "showfaceted": "false",
    "timezoneoffset": "-60",
    "facetedfields": "formats",
    "facetedkey": "formats|",
    "facetedvalue": "!Press Release|",
    "sort": "date",
    "additionalindexes": "4cd6f71fbf22424d,937d600b0d0d4e23,3bfbe40caee7443e,626fdfcd96444f28"
}

# Initialanfrage, um die Gesamtzahl der Ergebnisse zu ermitteln
response = requests.get(url, params=params)
if response.status_code == 200:
    data = response.json()
    total_results = data['metadata']['totalresults']
    total_requests_needed = math.ceil(total_results / batch_size)

    all_data = []  # Sammeln aller Daten hier

    for endindex in range(0, total_requests_needed * batch_size, batch_size):
        # Parameter aktualisieren für jede Anfrage
        params['endindex'] = endindex
        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            all_data.extend(data['results'])
            print(f"{int(endindex/batch_size)+1} von {total_requests_needed} Durchgängen ausgeführt. {len(all_data)} Artikel geladen.")
            
            # Speichern der Daten nach jeweils 100 geladenen Ergebnissen
            if len(all_data) % 100 == 0 or (int(endindex/batch_size)+1) == total_requests_needed:
                save_data(all_data)

            # Warten für eine zufällige Zeit zwischen 2 und 10 Sekunden
            wait_time = random.randint(2, 10)
            print(f"Warte {wait_time} Sekunden...")
            time.sleep(wait_time)
        else:
            print("Fehler bei der Anfrage:", response.status_code)
            break

    # Speichern der gesammelten Daten in einer Datei
    with open('CNBC_articles.json', 'w') as file:
        json.dump(all_data, file, indent=4)

    print("Gesamte Daten wurden erfolgreich heruntergeladen und gespeichert.")
else:
    print("Initialanfrage fehlgeschlagen:", response.status_code)
# Out:
# 1 von 1193 Durchgängen ausgeführt. 10 Artikel geladen.
# Warte 3 Sekunden...
# 2 von 1193 Durchgängen ausgeführt. 20 Artikel geladen.
# Warte 2 Sekunden...
# 3 von 1193 Durchgängen ausgeführt. 30 Artikel geladen.
# Warte 4 Sekunden...
# 4 von 1193 Durchgängen ausgeführt. 40 Artikel geladen.
# Warte 4 Sekunden...
# 5 von 1193 Durchgängen ausgeführt. 50 Artikel geladen.
# Warte 4 Sekunden...
# 6 von 1193 Durchgängen ausgeführt. 60 Artikel geladen.
# Warte 2 Sekunden...
# 7 von 1193 Durchgängen ausgeführt. 70 Artikel geladen.
# Warte 5 Sekunden...
# 8 von 1193 Durchgängen ausgeführt. 80 Artikel geladen.
# Warte 10 Sekunden...
# 9 von 1193 Durchgängen ausgeführt. 90 Artikel geladen.
# Warte 3 Sekunden...
# 10 von 1193 Durchgängen ausgeführt. 100 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 5 Sekunden...
# 11 von 1193 Durchgängen ausgeführt. 110 Artikel geladen.
# Warte 3 Sekunden...
# 12 von 1193 Durchgängen ausgeführt. 120 Artikel geladen.
# Warte 4 Sekunden...
# 13 von 1193 Durchgängen ausgeführt. 130 Artikel geladen.
# Warte 2 Sekunden...
# 14 von 1193 Durchgängen ausgeführt. 140 Artikel geladen.
# Warte 2 Sekunden...
# 15 von 1193 Durchgängen ausgeführt. 150 Artikel geladen.
# Warte 9 Sekunden...
# 16 von 1193 Durchgängen ausgeführt. 160 Artikel geladen.
# Warte 2 Sekunden...
# 17 von 1193 Durchgängen ausgeführt. 170 Artikel geladen.
# Warte 5 Sekunden...
# 18 von 1193 Durchgängen ausgeführt. 180 Artikel geladen.
# Warte 2 Sekunden...
# 19 von 1193 Durchgängen ausgeführt. 190 Artikel geladen.
# Warte 3 Sekunden...
# 20 von 1193 Durchgängen ausgeführt. 200 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 3 Sekunden...
# 21 von 1193 Durchgängen ausgeführt. 210 Artikel geladen.
# Warte 5 Sekunden...
# 22 von 1193 Durchgängen ausgeführt. 220 Artikel geladen.
# Warte 7 Sekunden...
# 23 von 1193 Durchgängen ausgeführt. 230 Artikel geladen.
# Warte 3 Sekunden...
# 24 von 1193 Durchgängen ausgeführt. 240 Artikel geladen.
# Warte 9 Sekunden...
# 25 von 1193 Durchgängen ausgeführt. 250 Artikel geladen.
# Warte 10 Sekunden...
# 26 von 1193 Durchgängen ausgeführt. 260 Artikel geladen.
# Warte 7 Sekunden...
# 27 von 1193 Durchgängen ausgeführt. 270 Artikel geladen.
# Warte 6 Sekunden...
# 28 von 1193 Durchgängen ausgeführt. 280 Artikel geladen.
# Warte 10 Sekunden...
# 29 von 1193 Durchgängen ausgeführt. 290 Artikel geladen.
# Warte 8 Sekunden...
# 30 von 1193 Durchgängen ausgeführt. 300 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 9 Sekunden...
# 31 von 1193 Durchgängen ausgeführt. 310 Artikel geladen.
# Warte 5 Sekunden...
# 32 von 1193 Durchgängen ausgeführt. 320 Artikel geladen.
# Warte 3 Sekunden...
# 33 von 1193 Durchgängen ausgeführt. 330 Artikel geladen.
# Warte 10 Sekunden...
# 34 von 1193 Durchgängen ausgeführt. 340 Artikel geladen.
# Warte 8 Sekunden...
# 35 von 1193 Durchgängen ausgeführt. 350 Artikel geladen.
# Warte 8 Sekunden...
# 36 von 1193 Durchgängen ausgeführt. 360 Artikel geladen.
# Warte 4 Sekunden...
# 37 von 1193 Durchgängen ausgeführt. 370 Artikel geladen.
# Warte 7 Sekunden...
# 38 von 1193 Durchgängen ausgeführt. 380 Artikel geladen.
# Warte 3 Sekunden...
# 39 von 1193 Durchgängen ausgeführt. 390 Artikel geladen.
# Warte 8 Sekunden...
# 40 von 1193 Durchgängen ausgeführt. 400 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 9 Sekunden...
# 41 von 1193 Durchgängen ausgeführt. 410 Artikel geladen.
# Warte 2 Sekunden...
# 42 von 1193 Durchgängen ausgeführt. 420 Artikel geladen.
# Warte 7 Sekunden...
# 43 von 1193 Durchgängen ausgeführt. 430 Artikel geladen.
# Warte 4 Sekunden...
# 44 von 1193 Durchgängen ausgeführt. 440 Artikel geladen.
# Warte 6 Sekunden...
# 45 von 1193 Durchgängen ausgeführt. 450 Artikel geladen.
# Warte 10 Sekunden...
# 46 von 1193 Durchgängen ausgeführt. 460 Artikel geladen.
# Warte 7 Sekunden...
# 47 von 1193 Durchgängen ausgeführt. 470 Artikel geladen.
# Warte 8 Sekunden...
# 48 von 1193 Durchgängen ausgeführt. 480 Artikel geladen.
# Warte 10 Sekunden...
# 49 von 1193 Durchgängen ausgeführt. 490 Artikel geladen.
# Warte 10 Sekunden...
# 50 von 1193 Durchgängen ausgeführt. 500 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 8 Sekunden...
# 51 von 1193 Durchgängen ausgeführt. 510 Artikel geladen.
# Warte 9 Sekunden...
# 52 von 1193 Durchgängen ausgeführt. 520 Artikel geladen.
# Warte 10 Sekunden...
# 53 von 1193 Durchgängen ausgeführt. 530 Artikel geladen.
# Warte 3 Sekunden...
# 54 von 1193 Durchgängen ausgeführt. 540 Artikel geladen.
# Warte 10 Sekunden...
# 55 von 1193 Durchgängen ausgeführt. 550 Artikel geladen.
# Warte 6 Sekunden...
# 56 von 1193 Durchgängen ausgeführt. 560 Artikel geladen.
# Warte 9 Sekunden...
# 57 von 1193 Durchgängen ausgeführt. 570 Artikel geladen.
# Warte 5 Sekunden...
# 58 von 1193 Durchgängen ausgeführt. 580 Artikel geladen.
# Warte 6 Sekunden...
# 59 von 1193 Durchgängen ausgeführt. 590 Artikel geladen.
# Warte 9 Sekunden...
# 60 von 1193 Durchgängen ausgeführt. 600 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 8 Sekunden...
# 61 von 1193 Durchgängen ausgeführt. 610 Artikel geladen.
# Warte 3 Sekunden...
# 62 von 1193 Durchgängen ausgeführt. 620 Artikel geladen.
# Warte 8 Sekunden...
# 63 von 1193 Durchgängen ausgeführt. 630 Artikel geladen.
# Warte 4 Sekunden...
# 64 von 1193 Durchgängen ausgeführt. 640 Artikel geladen.
# Warte 9 Sekunden...
# 65 von 1193 Durchgängen ausgeführt. 650 Artikel geladen.
# Warte 3 Sekunden...
# 66 von 1193 Durchgängen ausgeführt. 660 Artikel geladen.
# Warte 3 Sekunden...
# 67 von 1193 Durchgängen ausgeführt. 670 Artikel geladen.
# Warte 3 Sekunden...
# 68 von 1193 Durchgängen ausgeführt. 680 Artikel geladen.
# Warte 3 Sekunden...
# 69 von 1193 Durchgängen ausgeführt. 690 Artikel geladen.
# Warte 3 Sekunden...
# 70 von 1193 Durchgängen ausgeführt. 700 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 2 Sekunden...
# 71 von 1193 Durchgängen ausgeführt. 710 Artikel geladen.
# Warte 3 Sekunden...
# 72 von 1193 Durchgängen ausgeführt. 720 Artikel geladen.
# Warte 3 Sekunden...
# 73 von 1193 Durchgängen ausgeführt. 730 Artikel geladen.
# Warte 8 Sekunden...
# 74 von 1193 Durchgängen ausgeführt. 740 Artikel geladen.
# Warte 4 Sekunden...
# 75 von 1193 Durchgängen ausgeführt. 750 Artikel geladen.
# Warte 4 Sekunden...
# 76 von 1193 Durchgängen ausgeführt. 760 Artikel geladen.
# Warte 6 Sekunden...
# 77 von 1193 Durchgängen ausgeführt. 770 Artikel geladen.
# Warte 5 Sekunden...
# 78 von 1193 Durchgängen ausgeführt. 780 Artikel geladen.
# Warte 5 Sekunden...
# 79 von 1193 Durchgängen ausgeführt. 790 Artikel geladen.
# Warte 4 Sekunden...
# 80 von 1193 Durchgängen ausgeführt. 800 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 9 Sekunden...
# 81 von 1193 Durchgängen ausgeführt. 810 Artikel geladen.
# Warte 7 Sekunden...
# 82 von 1193 Durchgängen ausgeführt. 820 Artikel geladen.
# Warte 10 Sekunden...
# 83 von 1193 Durchgängen ausgeführt. 830 Artikel geladen.
# Warte 6 Sekunden...
# 84 von 1193 Durchgängen ausgeführt. 840 Artikel geladen.
# Warte 4 Sekunden...
# 85 von 1193 Durchgängen ausgeführt. 850 Artikel geladen.
# Warte 4 Sekunden...
# 86 von 1193 Durchgängen ausgeführt. 860 Artikel geladen.
# Warte 10 Sekunden...
# 87 von 1193 Durchgängen ausgeführt. 870 Artikel geladen.
# Warte 3 Sekunden...
# 88 von 1193 Durchgängen ausgeführt. 880 Artikel geladen.
# Warte 2 Sekunden...
# 89 von 1193 Durchgängen ausgeführt. 890 Artikel geladen.
# Warte 9 Sekunden...
# 90 von 1193 Durchgängen ausgeführt. 900 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 4 Sekunden...
# 91 von 1193 Durchgängen ausgeführt. 910 Artikel geladen.
# Warte 6 Sekunden...
# 92 von 1193 Durchgängen ausgeführt. 920 Artikel geladen.
# Warte 3 Sekunden...
# 93 von 1193 Durchgängen ausgeführt. 930 Artikel geladen.
# Warte 2 Sekunden...
# 94 von 1193 Durchgängen ausgeführt. 940 Artikel geladen.
# Warte 10 Sekunden...
# 95 von 1193 Durchgängen ausgeführt. 950 Artikel geladen.
# Warte 7 Sekunden...
# 96 von 1193 Durchgängen ausgeführt. 960 Artikel geladen.
# Warte 3 Sekunden...
# 97 von 1193 Durchgängen ausgeführt. 970 Artikel geladen.
# Warte 9 Sekunden...
# 98 von 1193 Durchgängen ausgeführt. 980 Artikel geladen.
# Warte 6 Sekunden...
# 99 von 1193 Durchgängen ausgeführt. 990 Artikel geladen.
# Warte 4 Sekunden...
# 100 von 1193 Durchgängen ausgeführt. 1000 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 3 Sekunden...
# 101 von 1193 Durchgängen ausgeführt. 1010 Artikel geladen.
# Warte 5 Sekunden...
# 102 von 1193 Durchgängen ausgeführt. 1020 Artikel geladen.
# Warte 10 Sekunden...
# 103 von 1193 Durchgängen ausgeführt. 1030 Artikel geladen.
# Warte 8 Sekunden...
# 104 von 1193 Durchgängen ausgeführt. 1040 Artikel geladen.
# Warte 3 Sekunden...
# 105 von 1193 Durchgängen ausgeführt. 1050 Artikel geladen.
# Warte 8 Sekunden...
# 106 von 1193 Durchgängen ausgeführt. 1060 Artikel geladen.
# Warte 5 Sekunden...
# 107 von 1193 Durchgängen ausgeführt. 1070 Artikel geladen.
# Warte 6 Sekunden...
# 108 von 1193 Durchgängen ausgeführt. 1080 Artikel geladen.
# Warte 3 Sekunden...
# 109 von 1193 Durchgängen ausgeführt. 1090 Artikel geladen.
# Warte 2 Sekunden...
# 110 von 1193 Durchgängen ausgeführt. 1100 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 10 Sekunden...
# 111 von 1193 Durchgängen ausgeführt. 1110 Artikel geladen.
# Warte 6 Sekunden...
# 112 von 1193 Durchgängen ausgeführt. 1120 Artikel geladen.
# Warte 5 Sekunden...
# 113 von 1193 Durchgängen ausgeführt. 1130 Artikel geladen.
# Warte 7 Sekunden...
# 114 von 1193 Durchgängen ausgeführt. 1140 Artikel geladen.
# Warte 4 Sekunden...
# 115 von 1193 Durchgängen ausgeführt. 1150 Artikel geladen.
# Warte 8 Sekunden...
# 116 von 1193 Durchgängen ausgeführt. 1160 Artikel geladen.
# Warte 7 Sekunden...
# 117 von 1193 Durchgängen ausgeführt. 1170 Artikel geladen.
# Warte 7 Sekunden...
# 118 von 1193 Durchgängen ausgeführt. 1180 Artikel geladen.
# Warte 5 Sekunden...
# 119 von 1193 Durchgängen ausgeführt. 1190 Artikel geladen.
# Warte 9 Sekunden...
# 120 von 1193 Durchgängen ausgeführt. 1200 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 5 Sekunden...
# 121 von 1193 Durchgängen ausgeführt. 1210 Artikel geladen.
# Warte 4 Sekunden...
# 122 von 1193 Durchgängen ausgeführt. 1220 Artikel geladen.
# Warte 6 Sekunden...
# 123 von 1193 Durchgängen ausgeführt. 1230 Artikel geladen.
# Warte 3 Sekunden...
# 124 von 1193 Durchgängen ausgeführt. 1240 Artikel geladen.
# Warte 2 Sekunden...
# 125 von 1193 Durchgängen ausgeführt. 1250 Artikel geladen.
# Warte 5 Sekunden...
# 126 von 1193 Durchgängen ausgeführt. 1260 Artikel geladen.
# Warte 8 Sekunden...
# 127 von 1193 Durchgängen ausgeführt. 1270 Artikel geladen.
# Warte 2 Sekunden...
# 128 von 1193 Durchgängen ausgeführt. 1280 Artikel geladen.
# Warte 9 Sekunden...
# 129 von 1193 Durchgängen ausgeführt. 1290 Artikel geladen.
# Warte 9 Sekunden...
# 130 von 1193 Durchgängen ausgeführt. 1300 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 2 Sekunden...
# 131 von 1193 Durchgängen ausgeführt. 1310 Artikel geladen.
# Warte 9 Sekunden...
# 132 von 1193 Durchgängen ausgeführt. 1320 Artikel geladen.
# Warte 4 Sekunden...
# 133 von 1193 Durchgängen ausgeführt. 1330 Artikel geladen.
# Warte 8 Sekunden...
# 134 von 1193 Durchgängen ausgeführt. 1340 Artikel geladen.
# Warte 3 Sekunden...
# 135 von 1193 Durchgängen ausgeführt. 1350 Artikel geladen.
# Warte 3 Sekunden...
# 136 von 1193 Durchgängen ausgeführt. 1360 Artikel geladen.
# Warte 2 Sekunden...
# 137 von 1193 Durchgängen ausgeführt. 1370 Artikel geladen.
# Warte 5 Sekunden...
# 138 von 1193 Durchgängen ausgeführt. 1380 Artikel geladen.
# Warte 8 Sekunden...
# 139 von 1193 Durchgängen ausgeführt. 1390 Artikel geladen.
# Warte 7 Sekunden...
# 140 von 1193 Durchgängen ausgeführt. 1400 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 5 Sekunden...
# 141 von 1193 Durchgängen ausgeführt. 1410 Artikel geladen.
# Warte 5 Sekunden...
# 142 von 1193 Durchgängen ausgeführt. 1420 Artikel geladen.
# Warte 4 Sekunden...
# 143 von 1193 Durchgängen ausgeführt. 1430 Artikel geladen.
# Warte 3 Sekunden...
# 144 von 1193 Durchgängen ausgeführt. 1440 Artikel geladen.
# Warte 6 Sekunden...
# 145 von 1193 Durchgängen ausgeführt. 1450 Artikel geladen.
# Warte 2 Sekunden...
# 146 von 1193 Durchgängen ausgeführt. 1460 Artikel geladen.
# Warte 10 Sekunden...
# 147 von 1193 Durchgängen ausgeführt. 1470 Artikel geladen.
# Warte 6 Sekunden...
# 148 von 1193 Durchgängen ausgeführt. 1480 Artikel geladen.
# Warte 6 Sekunden...
# 149 von 1193 Durchgängen ausgeführt. 1490 Artikel geladen.
# Warte 2 Sekunden...
# 150 von 1193 Durchgängen ausgeführt. 1500 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 3 Sekunden...
# 151 von 1193 Durchgängen ausgeführt. 1510 Artikel geladen.
# Warte 2 Sekunden...
# 152 von 1193 Durchgängen ausgeführt. 1520 Artikel geladen.
# Warte 6 Sekunden...
# 153 von 1193 Durchgängen ausgeführt. 1530 Artikel geladen.
# Warte 9 Sekunden...
# 154 von 1193 Durchgängen ausgeführt. 1540 Artikel geladen.
# Warte 7 Sekunden...
# 155 von 1193 Durchgängen ausgeführt. 1550 Artikel geladen.
# Warte 4 Sekunden...
# 156 von 1193 Durchgängen ausgeführt. 1560 Artikel geladen.
# Warte 5 Sekunden...
# 157 von 1193 Durchgängen ausgeführt. 1570 Artikel geladen.
# Warte 4 Sekunden...
# 158 von 1193 Durchgängen ausgeführt. 1580 Artikel geladen.
# Warte 7 Sekunden...
# 159 von 1193 Durchgängen ausgeführt. 1590 Artikel geladen.
# Warte 10 Sekunden...
# 160 von 1193 Durchgängen ausgeführt. 1600 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 8 Sekunden...
# 161 von 1193 Durchgängen ausgeführt. 1610 Artikel geladen.
# Warte 9 Sekunden...
# 162 von 1193 Durchgängen ausgeführt. 1620 Artikel geladen.
# Warte 5 Sekunden...
# 163 von 1193 Durchgängen ausgeführt. 1630 Artikel geladen.
# Warte 6 Sekunden...
# 164 von 1193 Durchgängen ausgeführt. 1640 Artikel geladen.
# Warte 3 Sekunden...
# 165 von 1193 Durchgängen ausgeführt. 1650 Artikel geladen.
# Warte 2 Sekunden...
# 166 von 1193 Durchgängen ausgeführt. 1660 Artikel geladen.
# Warte 10 Sekunden...
# 167 von 1193 Durchgängen ausgeführt. 1670 Artikel geladen.
# Warte 6 Sekunden...
# 168 von 1193 Durchgängen ausgeführt. 1680 Artikel geladen.
# Warte 6 Sekunden...
# 169 von 1193 Durchgängen ausgeführt. 1690 Artikel geladen.
# Warte 10 Sekunden...
# 170 von 1193 Durchgängen ausgeführt. 1700 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 8 Sekunden...
# 171 von 1193 Durchgängen ausgeführt. 1710 Artikel geladen.
# Warte 5 Sekunden...
# 172 von 1193 Durchgängen ausgeführt. 1720 Artikel geladen.
# Warte 5 Sekunden...
# 173 von 1193 Durchgängen ausgeführt. 1730 Artikel geladen.
# Warte 9 Sekunden...
# 174 von 1193 Durchgängen ausgeführt. 1740 Artikel geladen.
# Warte 6 Sekunden...
# 175 von 1193 Durchgängen ausgeführt. 1750 Artikel geladen.
# Warte 3 Sekunden...
# 176 von 1193 Durchgängen ausgeführt. 1760 Artikel geladen.
# Warte 9 Sekunden...
# 177 von 1193 Durchgängen ausgeführt. 1770 Artikel geladen.
# Warte 5 Sekunden...
# 178 von 1193 Durchgängen ausgeführt. 1780 Artikel geladen.
# Warte 10 Sekunden...
# 179 von 1193 Durchgängen ausgeführt. 1790 Artikel geladen.
# Warte 4 Sekunden...
# 180 von 1193 Durchgängen ausgeführt. 1800 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 9 Sekunden...
# 181 von 1193 Durchgängen ausgeführt. 1810 Artikel geladen.
# Warte 5 Sekunden...
# 182 von 1193 Durchgängen ausgeführt. 1820 Artikel geladen.
# Warte 8 Sekunden...
# 183 von 1193 Durchgängen ausgeführt. 1830 Artikel geladen.
# Warte 6 Sekunden...
# 184 von 1193 Durchgängen ausgeführt. 1840 Artikel geladen.
# Warte 4 Sekunden...
# 185 von 1193 Durchgängen ausgeführt. 1850 Artikel geladen.
# Warte 9 Sekunden...
# 186 von 1193 Durchgängen ausgeführt. 1860 Artikel geladen.
# Warte 9 Sekunden...
# 187 von 1193 Durchgängen ausgeführt. 1870 Artikel geladen.
# Warte 9 Sekunden...
# 188 von 1193 Durchgängen ausgeführt. 1880 Artikel geladen.
# Warte 4 Sekunden...
# 189 von 1193 Durchgängen ausgeführt. 1890 Artikel geladen.
# Warte 7 Sekunden...
# 190 von 1193 Durchgängen ausgeführt. 1900 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 7 Sekunden...
# 191 von 1193 Durchgängen ausgeführt. 1910 Artikel geladen.
# Warte 2 Sekunden...
# 192 von 1193 Durchgängen ausgeführt. 1920 Artikel geladen.
# Warte 3 Sekunden...
# 193 von 1193 Durchgängen ausgeführt. 1930 Artikel geladen.
# Warte 9 Sekunden...
# 194 von 1193 Durchgängen ausgeführt. 1940 Artikel geladen.
# Warte 4 Sekunden...
# 195 von 1193 Durchgängen ausgeführt. 1950 Artikel geladen.
# Warte 3 Sekunden...
# 196 von 1193 Durchgängen ausgeführt. 1960 Artikel geladen.
# Warte 10 Sekunden...
# 197 von 1193 Durchgängen ausgeführt. 1970 Artikel geladen.
# Warte 9 Sekunden...
# 198 von 1193 Durchgängen ausgeführt. 1980 Artikel geladen.
# Warte 6 Sekunden...
# 199 von 1193 Durchgängen ausgeführt. 1990 Artikel geladen.
# Warte 3 Sekunden...
# 200 von 1193 Durchgängen ausgeführt. 2000 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 9 Sekunden...
# 201 von 1193 Durchgängen ausgeführt. 2010 Artikel geladen.
# Warte 10 Sekunden...
# 202 von 1193 Durchgängen ausgeführt. 2020 Artikel geladen.
# Warte 10 Sekunden...
# 203 von 1193 Durchgängen ausgeführt. 2030 Artikel geladen.
# Warte 3 Sekunden...
# 204 von 1193 Durchgängen ausgeführt. 2040 Artikel geladen.
# Warte 8 Sekunden...
# 205 von 1193 Durchgängen ausgeführt. 2050 Artikel geladen.
# Warte 9 Sekunden...
# 206 von 1193 Durchgängen ausgeführt. 2060 Artikel geladen.
# Warte 10 Sekunden...
# 207 von 1193 Durchgängen ausgeführt. 2070 Artikel geladen.
# Warte 4 Sekunden...
# 208 von 1193 Durchgängen ausgeführt. 2080 Artikel geladen.
# Warte 6 Sekunden...
# 209 von 1193 Durchgängen ausgeführt. 2090 Artikel geladen.
# Warte 8 Sekunden...
# 210 von 1193 Durchgängen ausgeführt. 2100 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 4 Sekunden...
# 211 von 1193 Durchgängen ausgeführt. 2110 Artikel geladen.
# Warte 5 Sekunden...
# 212 von 1193 Durchgängen ausgeführt. 2120 Artikel geladen.
# Warte 7 Sekunden...
# 213 von 1193 Durchgängen ausgeführt. 2130 Artikel geladen.
# Warte 9 Sekunden...
# 214 von 1193 Durchgängen ausgeführt. 2140 Artikel geladen.
# Warte 5 Sekunden...
# 215 von 1193 Durchgängen ausgeführt. 2150 Artikel geladen.
# Warte 2 Sekunden...
# 216 von 1193 Durchgängen ausgeführt. 2160 Artikel geladen.
# Warte 5 Sekunden...
# 217 von 1193 Durchgängen ausgeführt. 2170 Artikel geladen.
# Warte 2 Sekunden...
# 218 von 1193 Durchgängen ausgeführt. 2180 Artikel geladen.
# Warte 2 Sekunden...
# 219 von 1193 Durchgängen ausgeführt. 2190 Artikel geladen.
# Warte 6 Sekunden...
# 220 von 1193 Durchgängen ausgeführt. 2200 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 9 Sekunden...
# 221 von 1193 Durchgängen ausgeführt. 2210 Artikel geladen.
# Warte 10 Sekunden...
# 222 von 1193 Durchgängen ausgeführt. 2220 Artikel geladen.
# Warte 7 Sekunden...
# 223 von 1193 Durchgängen ausgeführt. 2230 Artikel geladen.
# Warte 2 Sekunden...
# 224 von 1193 Durchgängen ausgeführt. 2240 Artikel geladen.
# Warte 5 Sekunden...
# 225 von 1193 Durchgängen ausgeführt. 2250 Artikel geladen.
# Warte 10 Sekunden...
# 226 von 1193 Durchgängen ausgeführt. 2260 Artikel geladen.
# Warte 4 Sekunden...
# 227 von 1193 Durchgängen ausgeführt. 2270 Artikel geladen.
# Warte 5 Sekunden...
# 228 von 1193 Durchgängen ausgeführt. 2280 Artikel geladen.
# Warte 9 Sekunden...
# 229 von 1193 Durchgängen ausgeführt. 2290 Artikel geladen.
# Warte 7 Sekunden...
# 230 von 1193 Durchgängen ausgeführt. 2300 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 3 Sekunden...
# 231 von 1193 Durchgängen ausgeführt. 2310 Artikel geladen.
# Warte 3 Sekunden...
# 232 von 1193 Durchgängen ausgeführt. 2320 Artikel geladen.
# Warte 2 Sekunden...
# 233 von 1193 Durchgängen ausgeführt. 2330 Artikel geladen.
# Warte 3 Sekunden...
# 234 von 1193 Durchgängen ausgeführt. 2340 Artikel geladen.
# Warte 8 Sekunden...
# 235 von 1193 Durchgängen ausgeführt. 2350 Artikel geladen.
# Warte 3 Sekunden...
# 236 von 1193 Durchgängen ausgeführt. 2360 Artikel geladen.
# Warte 6 Sekunden...
# 237 von 1193 Durchgängen ausgeführt. 2370 Artikel geladen.
# Warte 9 Sekunden...
# 238 von 1193 Durchgängen ausgeführt. 2380 Artikel geladen.
# Warte 8 Sekunden...
# 239 von 1193 Durchgängen ausgeführt. 2390 Artikel geladen.
# Warte 7 Sekunden...
# 240 von 1193 Durchgängen ausgeführt. 2400 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 9 Sekunden...
# 241 von 1193 Durchgängen ausgeführt. 2410 Artikel geladen.
# Warte 7 Sekunden...
# 242 von 1193 Durchgängen ausgeführt. 2420 Artikel geladen.
# Warte 8 Sekunden...
# 243 von 1193 Durchgängen ausgeführt. 2430 Artikel geladen.
# Warte 10 Sekunden...
# 244 von 1193 Durchgängen ausgeführt. 2440 Artikel geladen.
# Warte 10 Sekunden...
# 245 von 1193 Durchgängen ausgeführt. 2450 Artikel geladen.
# Warte 7 Sekunden...
# 246 von 1193 Durchgängen ausgeführt. 2460 Artikel geladen.
# Warte 3 Sekunden...
# 247 von 1193 Durchgängen ausgeführt. 2470 Artikel geladen.
# Warte 4 Sekunden...
# 248 von 1193 Durchgängen ausgeführt. 2480 Artikel geladen.
# Warte 6 Sekunden...
# 249 von 1193 Durchgängen ausgeführt. 2490 Artikel geladen.
# Warte 6 Sekunden...
# 250 von 1193 Durchgängen ausgeführt. 2500 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 10 Sekunden...
# 251 von 1193 Durchgängen ausgeführt. 2510 Artikel geladen.
# Warte 9 Sekunden...
# 252 von 1193 Durchgängen ausgeführt. 2520 Artikel geladen.
# Warte 5 Sekunden...
# 253 von 1193 Durchgängen ausgeführt. 2530 Artikel geladen.
# Warte 5 Sekunden...
# 254 von 1193 Durchgängen ausgeführt. 2540 Artikel geladen.
# Warte 5 Sekunden...
# 255 von 1193 Durchgängen ausgeführt. 2550 Artikel geladen.
# Warte 8 Sekunden...
# 256 von 1193 Durchgängen ausgeführt. 2560 Artikel geladen.
# Warte 3 Sekunden...
# 257 von 1193 Durchgängen ausgeführt. 2570 Artikel geladen.
# Warte 3 Sekunden...
# 258 von 1193 Durchgängen ausgeführt. 2580 Artikel geladen.
# Warte 5 Sekunden...
# 259 von 1193 Durchgängen ausgeführt. 2590 Artikel geladen.
# Warte 9 Sekunden...
# 260 von 1193 Durchgängen ausgeführt. 2600 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 5 Sekunden...
# 261 von 1193 Durchgängen ausgeführt. 2610 Artikel geladen.
# Warte 8 Sekunden...
# 262 von 1193 Durchgängen ausgeführt. 2620 Artikel geladen.
# Warte 4 Sekunden...
# 263 von 1193 Durchgängen ausgeführt. 2630 Artikel geladen.
# Warte 5 Sekunden...
# 264 von 1193 Durchgängen ausgeführt. 2640 Artikel geladen.
# Warte 8 Sekunden...
# 265 von 1193 Durchgängen ausgeführt. 2650 Artikel geladen.
# Warte 8 Sekunden...
# 266 von 1193 Durchgängen ausgeführt. 2660 Artikel geladen.
# Warte 10 Sekunden...
# 267 von 1193 Durchgängen ausgeführt. 2670 Artikel geladen.
# Warte 3 Sekunden...
# 268 von 1193 Durchgängen ausgeführt. 2680 Artikel geladen.
# Warte 2 Sekunden...
# 269 von 1193 Durchgängen ausgeführt. 2690 Artikel geladen.
# Warte 5 Sekunden...
# 270 von 1193 Durchgängen ausgeführt. 2700 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 4 Sekunden...
# 271 von 1193 Durchgängen ausgeführt. 2710 Artikel geladen.
# Warte 2 Sekunden...
# 272 von 1193 Durchgängen ausgeführt. 2720 Artikel geladen.
# Warte 2 Sekunden...
# 273 von 1193 Durchgängen ausgeführt. 2730 Artikel geladen.
# Warte 9 Sekunden...
# 274 von 1193 Durchgängen ausgeführt. 2740 Artikel geladen.
# Warte 2 Sekunden...
# 275 von 1193 Durchgängen ausgeführt. 2750 Artikel geladen.
# Warte 4 Sekunden...
# 276 von 1193 Durchgängen ausgeführt. 2760 Artikel geladen.
# Warte 5 Sekunden...
# 277 von 1193 Durchgängen ausgeführt. 2770 Artikel geladen.
# Warte 5 Sekunden...
# 278 von 1193 Durchgängen ausgeführt. 2780 Artikel geladen.
# Warte 2 Sekunden...
# 279 von 1193 Durchgängen ausgeführt. 2790 Artikel geladen.
# Warte 7 Sekunden...
# 280 von 1193 Durchgängen ausgeführt. 2800 Artikel geladen.
# Daten wurden erfolgreich zwischengespeichert.
# Warte 4 Sekunden...
# 281 von 1193 Durchgängen ausgeführt. 2810 Artikel geladen.
# Warte 5 Sekunden...
# 282 von 1193 Durchgängen ausgeführt. 2820 Artikel geladen.
# Warte 7 Sekunden...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/connectionpool.py:407, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
# --> 407     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#     408     raise
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/urllib3/connectionpool.py:358, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     357 if isinstance(err, SocketTimeout):
# --> 358     raise ReadTimeoutError(
#     359         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     360     )
#     362 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     363 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.queryly.com', port=443): Read timed out. (read timeout=None)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[3], line 43
#      40 for endindex in range(0, total_requests_needed * batch_size, batch_size):
#      41     # Parameter aktualisieren für jede Anfrage
#      42     params['endindex'] = endindex
# ---> 43     response = requests.get(url, params=params)
#      44     if response.status_code == 200:
#      45         data = response.json()
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/requests/adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     530     raise SSLError(e, request=request)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#     534     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='api.queryly.com', port=443): Read timed out. (read timeout=None)

# %% [markdown]
# ### Laden der einzelnen Artikel
#
# Da das vorherige Skript eine JSON mit allen Links zu den verfügbaren Artikeln erzeugt, gilt es nun die dort enthaltenen Artikel herunterzuladen.
#
# Die bereits erzeugte JSON enthält für jeden Artikel folgenden Eintrag, mit passendem Link zur Html Datei.
#
# ```cn:liveURL"https://www.cnbc.com/2024/03/22/faa-to-step-up-scrutiny-of-united-airlines-after-recent-incidents.html"```
#
#
# In der HTML der Artikel ist eine JSON eingebettet, die Text des Artikels enthält.
#
# Die JSON ist dabei in der Variable ``` <script charSet="UTF-8"> window.__s_data = {``` enthalten.
#
#
# ![alt text](screenshots/2.png "2")

# %% [markdown]
# Mittels BeautifulSoup und einer RegEx suche nach der genannten ```window.__s_data``` Variablen, wird die enthaltene JSNON extrahiert.

# %%
import requests
from bs4 import BeautifulSoup
import json
import re

# URL des Artikels
url = "https://www.cnbc.com/2024/03/22/airbus-says-its-not-happy-about-issues-at-rival-boeing.html"

# Anfrage an die URL senden und Antwort erhalten
response = requests.get(url)

# Überprüfen, ob die Anfrage erfolgreich war
if response.status_code == 200:
    html_content = response.text  # HTML-Inhalt der Antwort

    # Erstellen einer BeautifulSoup-Instanz und Parsen des HTML-Inhalts
    soup = BeautifulSoup(html_content, 'lxml')

    # Suche nach dem <script> Tag, der die gewünschten JSON-Daten enthält
    script_tag = soup.find('script', string=re.compile('window\.__s_data'))

    if script_tag:
        # Extrahieren des JavaScript-Codes als Text
        script_content = script_tag.string

        # Suchen des JSON-Teils im Script-Content mit einem regulären Ausdruck
        json_data_match = re.search(r'window\.__s_data\s*=\s*(\{.*?\});', script_content, re.DOTALL)

        if json_data_match:
            json_data_str = json_data_match.group(1)  # JSON als String

            # Umwandlung des String in ein Python-Dictionary
            json_data = json.loads(json_data_str)

            # Speichern der JSON-Daten in einer Datei
            with open('lists/extracted_json_data.json', 'w', encoding='utf-8') as json_file:
                json.dump(json_data, json_file, ensure_ascii=False, indent=4)
            
            print("Die JSON-Daten wurden erfolgreich gespeichert.")
        else:
            print("JSON-Daten konnten im Script-Tag nicht gefunden werden.")
    else:
        print("Entsprechender <script> Tag nicht gefunden.")
else:
    print(f"Fehler beim Abrufen der Seite: Statuscode {response.status_code}")
# Out:
# Die JSON-Daten wurden erfolgreich gespeichert.
